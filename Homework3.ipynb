# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/BA/blob/main/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Customer=pd.read_excel("https://github.com/ogut77/BA/blob/main/Customer.xlsx?raw=true")
Employee=pd.read_excel("https://github.com/ogut77/BA/blob/main/Employee.xlsx?raw=true")
Employee_1=pd.read_excel("https://github.com/ogut77/BA/blob/main/Employee.xlsx?raw=true")
Product=pd.read_excel("https://github.com/ogut77/BA/blob/main/Product.xlsx?raw=true")
OrdLine=pd.read_excel("https://github.com/ogut77/BA/blob/main/OrdLine.xlsx?raw=true")
OrderTbl=pd.read_excel("https://github.com/ogut77/BA/blob/main/OrderTbl.xlsx?raw=true")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.3.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.41)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (1.1.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.8.1)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=5a5493a52284ed686f0a1271134901380268f2f09f081ec05b3fe99b879610e7
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
OrderTbl.dtypes
# Out:
# OrdNo                object
# OrdDate      datetime64[ns]
# CustNo               object
# EmpNo                object
# OrdName              object
# OrdStreet            object
# OrdCity              object
# OrdState             object
# OrdZip               object
# dtype: object

# %%
#1-List the order number, order date, customer number, and customer name (first and last) of orders
# placed in January 2017 sent to Colorado recipients.
txt='''
select *
from OrderTbl
'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#        OrdNo                     OrdDate    CustNo     EmpNo  \
# 0   O1116324  2017-01-23 00:00:00.000000  C0954327  E8544399
# 1   O1231231  2017-01-23 00:00:00.000000  C9432910  E9954302
# 2   O1241518  2017-02-10 00:00:00.000000  C9549302      None
# 3   O1455122  2017-01-09 00:00:00.000000  C8574932  E9345771
# 4   O1579999  2017-01-05 00:00:00.000000  C9543029  E8544399
# 5   O1615141  2017-01-23 00:00:00.000000  C8654390  E8544399
# 6   O1656777  2017-02-11 00:00:00.000000  C8543321      None
# 7   O2233457  2017-01-12 00:00:00.000000  C2388597  E9884325
# 8   O2334661  2017-01-14 00:00:00.000000  C0954327  E1329594
# 9   O3252629  2017-01-23 00:00:00.000000  C9403348  E9954302
# 10  O3331222  2017-01-13 00:00:00.000000  C1010398      None
# 11  O3377543  2017-01-15 00:00:00.000000  C9128574  E8843211
# 12  O4714645  2017-01-11 00:00:00.000000  C2388597  E1329594
# 13  O5511365  2017-01-22 00:00:00.000000  C3340959  E9884325
# 14  O6565656  2017-01-20 00:00:00.000000  C9865874  E8843211
# 15  O7847172  2017-01-23 00:00:00.000000  C9943201      None
# 16  O7959898  2017-02-19 00:00:00.000000  C8543321  E8544399
# 17  O7989497  2017-01-16 00:00:00.000000  C3499503  E9345771
# 18  O8979495  2017-01-23 00:00:00.000000  C9865874      None
# 19  O9919699  2017-02-11 00:00:00.000000  C9857432  E9954302
#
#              OrdName           OrdStreet     OrdCity OrdState      OrdZip
# 0       Sheri Gordon        336 Hill St.   Littleton       CO  80129-5543
# 1       Larry Styles  9825 S. Crest Lane    Bellevue       WA  98104-2211
# 2         Todd Hayes        1400 NW 88th    Lynnwood       WA  98036-2244
# 3        Wally Jones     411 Webber Ave.     Seattle       WA  98105-1093
# 4        Tom Johnson      1632 Ocean Dr.  Des Moines       WA  98222-1123
# 5      Candy Kendall        456 Pine St.     Seattle       WA  98105-3345
# 6       Ron Thompson       789 122nd St.      Renton       WA  98666-1289
# 7        Beth Taylor      2396 Rafter Rd     Seattle       WA  98103-1121
# 8   Mrs. Ruth Gordon        233 S. 166th     Seattle       WA       98011
# 9         Mike Boren      642 Crest Ave.   Englewood       CO  80113-5431
# 10      Jim Glussman     1432 E. Ravenna      Denver       CO  80111-0033
# 11       Jerry Wyatt     16212 123rd Ct.      Denver       CO  80222-0022
# 12       Beth Taylor      2396 Rafter Rd     Seattle       WA  98103-1121
# 13       Betty White       4334 153rd NW     Seattle       WA  98178-3311
# 14   Mr. Jack Sibley        166 E. 344th      Renton       WA  98006-5543
# 15     Harry Sanders    1280 S. Hill Rd.        Fife       WA  98222-2258
# 16      Ron Thompson       789 122nd St.      Renton       WA  98666-1289
# 17          Bob Mann  1190 Lorraine Cir.      Monroe       WA  98013-1095
# 18       HelenSibley       206 McCaffrey      Renton       WA  98006-5543
# 19       Homer Wells        123 Main St.     Seattle       WA  98105-4322

# %%
#2-List the order number, order date, and customer number of orders placed before
#January 23, 2017, where customer address (CusState) is in Washington 'WA'
txt='''

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#       OrdNo                     OrdDate    CustNo     EmpNo           OrdName  \
# 0  O1455122  2017-01-09 00:00:00.000000  C8574932  E9345771       Wally Jones
# 1  O1579999  2017-01-05 00:00:00.000000  C9543029  E8544399       Tom Johnson
# 2  O2233457  2017-01-12 00:00:00.000000  C2388597  E9884325       Beth Taylor
# 3  O2334661  2017-01-14 00:00:00.000000  C0954327  E1329594  Mrs. Ruth Gordon
# 4  O3331222  2017-01-13 00:00:00.000000  C1010398      None      Jim Glussman
# 5  O3377543  2017-01-15 00:00:00.000000  C9128574  E8843211       Jerry Wyatt
# 6  O4714645  2017-01-11 00:00:00.000000  C2388597  E1329594       Beth Taylor
# 7  O5511365  2017-01-22 00:00:00.000000  C3340959  E9884325       Betty White
# 8  O6565656  2017-01-20 00:00:00.000000  C9865874  E8843211   Mr. Jack Sibley
# 9  O7989497  2017-01-16 00:00:00.000000  C3499503  E9345771          Bob Mann
#
#             OrdStreet     OrdCity OrdState      OrdZip
# 0     411 Webber Ave.     Seattle       WA  98105-1093
# 1      1632 Ocean Dr.  Des Moines       WA  98222-1123
# 2      2396 Rafter Rd     Seattle       WA  98103-1121
# 3        233 S. 166th     Seattle       WA       98011
# 4     1432 E. Ravenna      Denver       CO  80111-0033
# 5     16212 123rd Ct.      Denver       CO  80222-0022
# 6      2396 Rafter Rd     Seattle       WA  98103-1121
# 7       4334 153rd NW     Seattle       WA  98178-3311
# 8        166 E. 344th      Renton       WA  98006-5543
# 9  1190 Lorraine Cir.      Monroe       WA  98013-1095

# %%
#3-List the order number, order date, customer number, and customer name
#(first and last) of orders placed in January 2017 placed by Colorado customers
#(CustState) but sent to Washington recipients (OrdState).
txt='''

'''
Q3 =  psql.sqldf(txt)
Q3

# %%
#4-List the customer number, name (first and last), and balance of Washington
#customers who have placed one or more orders in February 2017. 
txt='''

'''
Q4 =  psql.sqldf(txt)
Q4
# Out:
#      CustNo CustFirstName CustLastName       CustStreet   CustCity CustState  \
# 0  C0954327         Sheri       Gordon     336 HiII St.  Littleton        CO
# 1  C1010398           Jim     Glussman  1432 E. Ravenna     Denver        CO
# 2  C2388597          Beth       Taylor   2396 Rafter Rd    Seattle        WA
# 3  C3340959         Betty         Wise    4334 153rd NW    Seattle        WA
# 4  C8574932         Wally        Jones  411 Webber Ave.    Seattle        WA
# 5  C8654390         Candy      Kendall     456 Pine St.    Seattle        WA
# 6  C9128574         Jerry        Wyatt  16212 123rd Ct.     Denver        CO
# 7  C9403348          Mike        Boren   642 Crest Ave.  Englewood        CO
# 8  C9857432         Homer        Wells     123 Main St.    Seattle        WA
# 9  C9865874          Mary         Hill    206 McCaffrey  Littleton        CO
#
#       CustZip  CustBal
# 0  80129-5543      230
# 1  80111-0033      200
# 2  98103-1121      500
# 3  98178-3311      200
# 4  98105-1093     1500
# 5  98105-3345       50
# 6  80222-0022      100
# 7  80113-5431        0
# 8  98105-4322      500
# 9  80129-5543      150

# %%
#5-List the customer number, name (first and last), and balance of Washington
#customers who have placed  more than 1 order in February 2017. 
txt='''

'''
Q5 =  psql.sqldf(txt)
Q5

# %%
#6-Find prodcts information if product price is lower than average price
txt='''

'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#    Number of Customer with 0 Balance
# 0                                  3

# %%
#7-if product price is lower than average price, find how many times are they ordered?
txt='''

'''
Q7 =  psql.sqldf(txt)
Q7

# %%
#8-List the order number and total amount for orders placed each day.

txt='''

'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036566      17 inch Color Monitor  ColorMeg, Inc.       12     169.00
# 1  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10     319.00
# 2  P1114590  R3000 Color Laser Printer          Connex        5     699.00
# 3  P1556678  CVP Ink Jet Color Printer          Connex        8      99.00
# 4  P3455443    Color Ink Jet Cartridge          Connex       24      38.00
# 5  P4200344       36-Bit Color Scanner   UV Components       16     199.99
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-02-20 00:00:00.000000
# 2  2017-01-22 00:00:00.000000
# 3  2017-01-22 00:00:00.000000
# 4  2017-01-22 00:00:00.000000
# 5  2017-01-29 00:00:00.000000

# %%
#9-List the total commission earned by each employee in each month of 2017.
txt='''


'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#    MinPrice  MaxPrice  AvgPrice  NumberofProduct
# 0      12.0     699.0   166.567               10

# %%
#10-What is the total value of product sold by each employee?
#Included internet orders as well
txt='''

'''
Q10=  psql.sqldf(txt)
Q10
# Out:
#           ProdMfg  Total Value of Product at Hand
# 0  ColorMeg, Inc.                         5218.00
# 1          Connex                         6329.36
# 2         Cybercx                         1068.00
# 3         Ethlite                         1200.00
# 4       Intersafe                          494.67
# 5   UV Components                         3199.84

# %%
#11-List the customer firstand last name and order number and employee first name and last name.
#If order is internet order, include them as well
#Note:If order is internet order, employee first name and last name will be null
txt='''

'''
Q11=  psql.sqldf(txt)
Q11

# %%
#12- List product information which is not ordered?
#Note: if here is not such product, nothing other than column name will be displayed.
txt='''

'''
Q12=  psql.sqldf(txt)
Q12

# %%
#13- List order information  where customer name (Customer First Name + Last Name) is the same as Order name
txt='''

'''
Q13=  psql.sqldf(txt)
Q13

# %%
#7-List the total commission earned by each employee. Include supervisor last name and first name if any.
#If employee does not havesupervisor, supervisor last name and first name will be null.
txt='''
'''
Q14 =  psql.sqldf(txt)
Q14
# Out:
#        OrdNo  Number of Product
# 0   O1116324                    1
# 1   O1231231                    1
# 2   O1233131                    1
# 3   O1241518                    1
# 4   O1455122                    1
# 5   O1579999                    3
# 6   O1615141                    3
# 7   O1656777                    2
# 8   O2233457                    2
# 9   O2334661                    3
# 10  O3252629                    2
# 11  O3331222                    1
# 12   O333222                    2
# 13  O3377543                    2
# 14  O4714645                    2
# 15  O5511365                    5
# 16  O6565656                    1
# 17  O7847172                    2
# 18  O7959898                    4
# 19  O7989497                    3
# 20  O8979495                    3
# 21  O9919699                    3

# %%
#15-List the number of orders and vlaue of it  handled by each employee. List employerr first name and last name if
#There is associated firs name and last name
txt='''
select Employee.EmpNo,EmpFirstName,EmpLastName,count(*) as 'Number of Orders Handled'
From OrderTbl left join Employee on OrderTbl.EmpNo=Employee.EmpNo
Group by Employee.EmpNo
'''
Q15 =  psql.sqldf(txt)
Q15
# Out:
#       EmpNo EmpFirstName EmpLastName  Number of Orders Handled
# 0      None         None        None                         5
# 1  E1329594        Landi      Santos                         2
# 2  E8544399          Joe     Jenkins                         4
# 3  E8843211          Amy        Tang                         2
# 4  E9345771        Colin       White                         2
# 5  E9884325       Thomas     Johnson                         2
# 6  E9954302         Mary        Hill                         3

# %%
#9-How many times each product are ordered?
txt='''

'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#      ProdNo  count(*)
# 0  P0036566         5
# 1  P0036577         3
# 2  P1114590         3
# 3  P1412138         6
# 4  P1445671         9
# 5  P1556678         7
# 6  P3455443         3
# 7  P4200344         4
# 8  P6677900         4
# 9  P9995676         4

# %%
#10-Combine Names (CustFirstName and CustLastName) form Customer table 
#with neames from Employee Table (EmpFirstName and EmpLastName )
txt='''


'''
Q10 =  psql.sqldf(txt)
Q10
# Out:
#    FirstName  LastName
# 0        Amy      Tang
# 1       Beth    Taylor
# 2      Betty      Wise
# 3        Bob      Mann
# 4      Candy   Kendall
# 5      Colin     White
# 6      Harry   Sanders
# 7      Homer     Wells
# 8      Jerry     Wyatt
# 9        Jim  Glussman
# 10       Joe   Jenkins
# 11     Landi    Santos
# 12     Larry    Styles
# 13      Mary      Hill
# 14      Mike     Boren
# 15       Ron  Thompson
# 16    Sharon   Johnson
# 17     Sheri    Gordon
# 18   Theresa      Beck
# 19    Thomas   Johnson
# 20      Todd     Hayes
# 21     Wally     Jones

# %%
#11-Find name (First and last name) that both appers in Employee and Customer Table
txt='''

'''
Q11 =  psql.sqldf(txt)
Q11
# Out:
#   FirstName LastName
# 0      Mary     Hill

# %%
#12-Find name (First aand last name) that appers in Employee but not  Customer Table
txt='''

'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#   FirstName LastName
# 0       Amy     Tang
# 1     Colin    White
# 2       Joe  Jenkins
# 3     Landi   Santos
# 4   Theresa     Beck
# 5    Thomas  Johnson

# %%
#13-Find name (First aand last name) that appers in Employee but not  Customer Table
txt='''

'''
Q13 =  psql.sqldf(txt)
Q13
# Out:
#    FirstName  LastName
# 0       Beth    Taylor
# 1      Betty      Wise
# 2        Bob      Mann
# 3      Candy   Kendall
# 4      Harry   Sanders
# 5      Homer     Wells
# 6      Jerry     Wyatt
# 7        Jim  Glussman
# 8      Larry    Styles
# 9       Mike     Boren
# 10       Ron  Thompson
# 11    Sharon   Johnson
# 12     Sheri    Gordon
# 13      Todd     Hayes
# 14     Wally     Jones

# %%
#14. List the average balance and number of customers by city. Only include
#customers residing in Washington State (WA).
txt='''

'''
Q14 =  psql.sqldf(txt)
Q14
# Out:
#    CustCity  AvgCustBal  Number of Customer
# 0  Bellevue       250.0                   1
# 1      Fife       928.0                   2
# 2  Lynnwood         0.0                   1
# 3    Monroe         0.0                   1
# 4    Renton        85.0                   1
# 5   Seattle       550.0                   5

# %%
#15. How many product are there without ProdNextShipDate. 
#What is their average price?
txt='''

'''
Q15 =  psql.sqldf(txt)
Q15
# Out:
#    Number of Product  AvgProdPrice
# 0                  3         17.56
