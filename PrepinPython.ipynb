# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/BA/blob/main/PrepinPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

os2015=pd.read_csv('https://raw.githubusercontent.com/ogut77/BA/main/orders_south_2015.csv', encoding='latin-1')
os2016=pd.read_csv('https://raw.githubusercontent.com/ogut77/BA/main/orders_south_2016.csv', encoding='latin-1')
os2017=pd.read_csv('https://raw.githubusercontent.com/ogut77/BA/main/orders_south_2017.csv', encoding='latin-1')
os2018=pd.read_csv('https://raw.githubusercontent.com/ogut77/BA/main/orders_south_2018.csv', encoding='latin-1')

# %%
pd.set_option('display.max_columns', 500)

# %%
print(os2015.columns)
print(os2016.columns)
print(os2017.columns)
print(os2018.columns)
print(os2015.shape)
print(os2016.shape)
print(os2017.shape)
print(os2018.shape)
# Out:
# Index(['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State', 'Row ID',
#        'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name'],
#       dtype='object')
# Index(['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State', 'Row ID',
#        'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name'],
#       dtype='object')
# Index(['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State', 'Row ID',
#        'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name'],
#       dtype='object')
# ...

# %%
frames = [os2015, os2016, os2017,os2018]

os = pd.concat(frames)
os
# Out:
#        Sales  Quantity    Profit  Discount Region           State  Row ID  \
# 0    503.960         4  131.0296       0.0  South       Louisiana     183
# 1    149.950         5   41.9860       0.0  South       Louisiana     184
# 2     29.000         2    7.2500       0.0  South       Louisiana     185
# 3     18.648         7  -12.4320       0.7  South  North Carolina     231
# 4    178.384         2   22.2980       0.2  South         Florida     315
# ..       ...       ...       ...       ...    ...             ...     ...
# 513  194.848         4   12.1780       0.2  South  North Carolina    9808
# 514  242.352         3   15.1470       0.2  South  North Carolina    9830
# 515   18.000         1    3.2400       0.0  South        Kentucky    9961
# 516   79.990         1   28.7964       0.0  South         Georgia    9988
# 517  206.100         5   55.6470       0.0  South         Georgia    9989
#
#            Order ID       Order Date        Ship Date  ... Customer ID  \
# ...

# %%
os['Order Date'] = pd.to_datetime(os['Order Date'])
os['Ship Date'] = pd.to_datetime(os['Ship Date'])
os
# Out:
#        Sales  Quantity    Profit  Discount Region           State  Row ID  \
# 0    503.960         4  131.0296       0.0  South       Louisiana     183
# 1    149.950         5   41.9860       0.0  South       Louisiana     184
# 2     29.000         2    7.2500       0.0  South       Louisiana     185
# 3     18.648         7  -12.4320       0.7  South  North Carolina     231
# 4    178.384         2   22.2980       0.2  South         Florida     315
# ..       ...       ...       ...       ...    ...             ...     ...
# 513  194.848         4   12.1780       0.2  South  North Carolina    9808
# 514  242.352         3   15.1470       0.2  South  North Carolina    9830
# 515   18.000         1    3.2400       0.0  South        Kentucky    9961
# 516   79.990         1   28.7964       0.0  South         Georgia    9988
# 517  206.100         5   55.6470       0.0  South         Georgia    9989
#
#            Order ID Order Date  Ship Date  ... Customer ID     Customer Name  \
# ...

# %%
oc=pd.read_csv('https://raw.githubusercontent.com/ogut77/BA/main/Orders_Central.csv', encoding='latin-1')

# %%
print(oc.columns)
print(len(oc.columns))
oc.head()
# Out:
# Index(['Row ID', 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Product ID',
#        'Category', 'Sub-Category', 'Product', 'Sales', 'Quantity', 'Profit',
#        'Order Year', 'Order Month', 'Order Day', 'Ship Year', 'Ship Month',
#        'Ship Day', 'Discounts'],
#       dtype='object')
# 24
#    Row ID        Order ID       Ship Mode Customer ID  Customer Name  \
# 0      15  US-2016-118983  Standard Class    HP-14815  Harold Pawlan
# 1      16  US-2016-118983  Standard Class    HP-14815  Harold Pawlan
# 2      17  CA-2015-105893  Standard Class    PK-19075      Pete Kriz
# 3      22  CA-2017-137330  Standard Class    KB-16585      Ken Black
# 4      23  CA-2017-137330  Standard Class    KB-16585      Ken Black
#
#        Segment        Country        City      State  Postal Code  ...  \
# 0  Home Office  United States  Fort Worth      Texas        76106  ...
# ...

# %%
dif1 = os.columns.difference(oc.columns)
print(dif1)
dif2 = oc.columns.difference(os.columns)
print(dif2)
# Out:
# Index(['Discount', 'Order Date', 'Product Name', 'Region', 'Ship Date'], dtype='object')
# Index(['Discounts', 'Order Day', 'Order Month', 'Order Year', 'Product',
#        'Ship Day', 'Ship Month', 'Ship Year'],
#       dtype='object')

# %%
oc = oc.rename(columns={'Discounts': 'Discount'})
oc = oc.rename(columns={'Product': 'Product Name'})
dif2 = oc.columns.difference(os.columns)
print(dif2)
# Out:
# Index(['Order Day', 'Order Month', 'Order Year', 'Ship Day', 'Ship Month',
#        'Ship Year'],
#       dtype='object')

# %%
from datetime import datetime

# Create a datetime object
oc['Order Date'] = pd.to_datetime(dict(month=oc['Order Month'],day=oc['Order Day'],year=oc['Order Year']))
oc['Ship Date']= pd.to_datetime(dict(month=oc['Ship Month'],day=oc['Ship Day'],year=oc['Ship Year']))
oc
# Out:
#       Row ID        Order ID       Ship Mode Customer ID     Customer Name  \
# 0         15  US-2016-118983  Standard Class    HP-14815     Harold Pawlan
# 1         16  US-2016-118983  Standard Class    HP-14815     Harold Pawlan
# 2         17  CA-2015-105893  Standard Class    PK-19075         Pete Kriz
# 3         22  CA-2017-137330  Standard Class    KB-16585         Ken Black
# 4         23  CA-2017-137330  Standard Class    KB-16585         Ken Black
# ...      ...             ...             ...         ...               ...
# 2318    9962  CA-2016-168088     First Class    CM-12655  Corinna Mitchell
# 2319    9963  CA-2016-168088     First Class    CM-12655  Corinna Mitchell
# 2320    9973  CA-2017-130225  Standard Class    RC-19960        Ryan Crowe
# 2321    9983  US-2017-157728  Standard Class    RC-19960        Ryan Crowe
# 2322    9984  US-2017-157728  Standard Class    RC-19960        Ryan Crowe
#
# ...

# %%
oc['Discount'] = oc['Discount'].replace({'None':0}, regex=True)
oc['Discount']
# Out:
# 0        0.8
# 1        0.8
# 2          0
# 3          0
# 4          0
#         ...
# 2318     0.2
# 2319    0.32
# 2320     0.2
# 2321       0
# 2322       0
# Name: Discount, Length: 2323, dtype: object

# %%
oc.columns
# Out:
# Index(['Row ID', 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Profit', 'Order Year', 'Order Month', 'Order Day', 'Ship Year',
#        'Ship Month', 'Ship Day', 'Discount', 'Order Date', 'Ship Date'],
#       dtype='object')

# %%
oc['Region']='Central'

# %%
oe=pd.read_excel('https://raw.githubusercontent.com/ogut77/BA/main/Orders_East.xlsx')
oe.head()
# Out:
#           Category          City        Country Customer ID    Customer Name  \
# 0        Furniture  Philadelphia  United States    SF-20065  Sandra Flanagan
# 1  Office Supplies  Philadelphia  United States    TB-21520  Tracy Blumstein
# 2  Office Supplies  Philadelphia  United States    TB-21520  Tracy Blumstein
# 3  Office Supplies  Philadelphia  United States    FH-14365     Fred Hopkins
# 4       Technology        Medina  United States    VW-21775  Victoria Wilson
#
#    Discount Order Date        Order ID  Postal Code       Product ID  ...  \
# 0       0.3 2018-07-16  US-2018-156909      19140.0  FUR-CH-10002774  ...
# 1       0.7 2016-09-17  US-2016-150630      19140.0  OFF-BI-10000474  ...
# 2       0.7 2016-09-17  US-2016-150630      19140.0  OFF-BI-10001525  ...
# 3       0.7 2018-07-06  US-2018-124303      19120.0  OFF-BI-10000343  ...
# 4       0.7 2016-01-02  CA-2016-146262      44256.0  TEC-MA-10000864  ...
#
# ...

# %%
oe['Sales'] = oe['Sales'].replace({'USD':''}, regex=True)
oe['Sales']
# Out:
# 0        71.37
# 1         9.61
# 2         6.85
# 3         2.94
# 4         1188
#          ...
# 2841     40.20
# 2842    735.98
# 2843     22.75
# 2844      31.5
# 2845     55.60
# Name: Sales, Length: 2846, dtype: object

# %%
oe.columns
dif3 = oe.columns.difference(os.columns)
print(dif3)
# Out:
# Index([], dtype='object')

# %%
ow=pd.read_csv('https://raw.githubusercontent.com/ogut77/BA/main/Orders_West.csv', encoding='latin-1')
ow.head()
# Out:
#    Row ID        Order ID           Order Date            Ship Date  \
# 0    3836  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 1    3837  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 2    3836  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 3    3837  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 4    4565  CA-2015-101175  2015-12-09 00:00:00  2015-12-14 00:00:00
#
#         Ship Mode Customer ID Customer Name    Segment        Country  \
# 0  Standard Class    JM-15655   Jim Mitchum  Corporate  United States
# 1  Standard Class    JM-15655   Jim Mitchum  Corporate  United States
# 2  Standard Class    JM-15655   Jim Mitchum  Corporate  United States
# 3  Standard Class    JM-15655   Jim Mitchum  Corporate  United States
# 4  Standard Class    DM-12955  Dario Medina  Corporate  United States
#
#        City  ...  Right_Region Right_Product ID   Right_Category  \
# 0  Glendale  ...          West  OFF-FA-10000611  Office Supplies
# ...

# %%
dif3 = ow.columns.difference(os.columns)
print(dif3)
# Out:
# Index(['Right_Category', 'Right_City', 'Right_Country', 'Right_Customer ID',
#        'Right_Customer Name', 'Right_Discount', 'Right_Order Date',
#        'Right_Postal Code', 'Right_Product ID', 'Right_Product Name',
#        'Right_Profit', 'Right_Quantity', 'Right_Region', 'Right_Row ID',
#        'Right_Sales', 'Right_Segment', 'Right_Ship Date', 'Right_Ship Mode',
#        'Right_State2', 'Right_Sub-Category'],
#       dtype='object')

# %%
ow.drop(['Right_Category', 'Right_City', 'Right_Country', 'Right_Customer ID',
       'Right_Customer Name', 'Right_Discount', 'Right_Order Date',
       'Right_Postal Code', 'Right_Product ID', 'Right_Product Name',
       'Right_Profit', 'Right_Quantity', 'Right_Region', 'Right_Row ID',
       'Right_Sales', 'Right_Segment', 'Right_Ship Date', 'Right_Ship Mode',
       'State', 'Right_Sub-Category'],axis=1,inplace=True)

# %%
ow.columns
dif3 = ow.columns.difference(os.columns)
print(dif3)
# Out:
# Index(['Right_State2'], dtype='object')

# %%
ow.rename(columns = {'Right_State2':'State'}, inplace = True)
ow
# Out:
#       Row ID        Order ID           Order Date            Ship Date  \
# 0       3836  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 1       3837  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 2       3836  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 3       3837  CA-2015-100363  2015-04-08 00:00:00  2015-04-15 00:00:00
# 4       4565  CA-2015-101175  2015-12-09 00:00:00  2015-12-14 00:00:00
# ...      ...             ...                  ...                  ...
# 9548    6234  US-2018-142188  2018-09-11 00:00:00  2018-09-11 00:00:00
# 9549    6235  US-2018-142188  2018-09-11 00:00:00  2018-09-11 00:00:00
# 9550    6236  US-2018-142188  2018-09-11 00:00:00  2018-09-11 00:00:00
# 9551    8294  US-2018-168802  2018-11-03 00:00:00  2018-11-07 00:00:00
# 9552    5870  CA-2017-152247  2017-11-07 00:00:00  2017-11-12 00:00:00
#
#            Ship Mode Customer ID      Customer Name      Segment  \
# ...

# %%
ow['Order Date'] = pd.to_datetime(ow['Order Date'])
ow['Ship Date'] = pd.to_datetime(ow['Ship Date'])
ow
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       3836  CA-2015-100363 2015-04-08 2015-04-15  Standard Class
# 1       3837  CA-2015-100363 2015-04-08 2015-04-15  Standard Class
# 2       3836  CA-2015-100363 2015-04-08 2015-04-15  Standard Class
# 3       3837  CA-2015-100363 2015-04-08 2015-04-15  Standard Class
# 4       4565  CA-2015-101175 2015-12-09 2015-12-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9548    6234  US-2018-142188 2018-09-11 2018-09-11        Same Day
# 9549    6235  US-2018-142188 2018-09-11 2018-09-11        Same Day
# 9550    6236  US-2018-142188 2018-09-11 2018-09-11        Same Day
# 9551    8294  US-2018-168802 2018-11-03 2018-11-07  Standard Class
# 9552    5870  CA-2017-152247 2017-11-07 2017-11-12  Standard Class
#
#      Customer ID      Customer Name      Segment        Country      City  \
# 0       JM-15655        Jim Mitchum    Corporate  United States  Glendale
# ...

# %%
os2=os[['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State','Row ID',
       'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
       'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
       'Product ID', 'Category', 'Sub-Category', 'Product Name']]
ow2=ow[['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State','Row ID',
       'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
       'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
       'Product ID', 'Category', 'Sub-Category', 'Product Name']]
oe2=oe[['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State','Row ID',
       'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
       'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
       'Product ID', 'Category', 'Sub-Category', 'Product Name']]
oc2=oc[['Sales', 'Quantity', 'Profit', 'Discount', 'Region', 'State','Row ID',
       'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
       'Customer Name', 'Segment', 'Country', 'City', 'Postal Code',
       'Product ID', 'Category', 'Sub-Category', 'Product Name']]

# %%
frames = [os2, oc2, oe2,ow2]

oall = pd.concat(frames)

oall
# Out:
#          Sales  Quantity    Profit Discount Region           State  Row ID  \
# 0       503.96       4.0  131.0296      0.0  South       Louisiana   183.0
# 1       149.95       5.0   41.9860      0.0  South       Louisiana   184.0
# 2         29.0       2.0    7.2500      0.0  South       Louisiana   185.0
# 3       18.648       7.0  -12.4320      0.7  South  North Carolina   231.0
# 4      178.384       2.0   22.2980      0.2  South         Florida   315.0
# ...        ...       ...       ...      ...    ...             ...     ...
# 9548     71.28      11.0   34.2144      0.0   West      Washington  6234.0
# 9549   1471.96       5.0  459.9875      0.2   West      Washington  6235.0
# 9550     79.96       5.0  -17.9910      0.2   West      Washington  6236.0
# 9551    18.368       4.0    5.9696      0.2   West      Washington  8294.0
# 9552  1603.136       4.0  100.1960      0.2   West         Wyoming  5870.0
#
#             Order ID Order Date  Ship Date  ... Customer ID  \
# ...
