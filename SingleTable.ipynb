# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/BA/blob/main/SingleTable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Customer=pd.read_excel("https://github.com/ogut77/BA/blob/main/Customer.xlsx?raw=true")
Employee=pd.read_excel("https://github.com/ogut77/BA/blob/main/Employee.xlsx?raw=true")
Employee_1=pd.read_excel("https://github.com/ogut77/BA/blob/main/Employee.xlsx?raw=true")
Product=pd.read_excel("https://github.com/ogut77/BA/blob/main/Product.xlsx?raw=true")
OrdLine=pd.read_excel("https://github.com/ogut77/BA/blob/main/OrdLine.xlsx?raw=true")
OrderTbl=pd.read_excel("https://github.com/ogut77/BA/blob/main/OrderTbl.xlsx?raw=true")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=f9c90d3f2011cf40cc54ebd2ff8c38fb6068cb4ec6917a78b961c58249a1b869
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A) Retrieve all columns from a table

# %%
#Query 1- List all columns and rows of the Customer table.
# * display all fields (columns) for selected table
txt='''


'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#       CustNo CustFirstName CustLastName          CustStreet   CustCity  \
# 0   C0954327         Sheri       Gordon        336 HiII St.  Littleton
# 1   C1010398           Jim     Glussman     1432 E. Ravenna     Denver
# 2   C2388597          Beth       Taylor      2396 Rafter Rd    Seattle
# 3   C3340959         Betty         Wise       4334 153rd NW    Seattle
# 4   C3499503           Bob         Mann  1190 Lorraine Cir.     Monroe
# 5   C8543321           Ron     Thompson       789 122nd St.     Renton
# 6   C8574932         Wally        Jones     411 Webber Ave.    Seattle
# 7   C8654390         Candy      Kendall        456 Pine St.    Seattle
# 8   C9128574         Jerry        Wyatt     16212 123rd Ct.     Denver
# 9   C9403348          Mike        Boren      642 Crest Ave.  Englewood
# 10  C9432910         Larry       Styles  9825 S. Crest Lane   Bellevue
# 11  C9543029        Sharon      Johnson      1223 Meyer Way       Fife
# ...

# %%
#Query 2- List all columns and rows of the Order table (OrderTbl).
txt='''

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#        OrdNo                     OrdDate    CustNo     EmpNo  \
# 0   O1116324  2017-01-23 00:00:00.000000  C0954327  E8544399
# 1   O1231231  2017-01-23 00:00:00.000000  C9432910  E9954302
# 2   O1241518  2017-02-10 00:00:00.000000  C9549302      None
# 3   O1455122  2017-01-09 00:00:00.000000  C8574932  E9345771
# 4   O1579999  2017-01-05 00:00:00.000000  C9543029  E8544399
# 5   O1615141  2017-01-23 00:00:00.000000  C8654390  E8544399
# 6   O1656777  2017-02-11 00:00:00.000000  C8543321      None
# 7   O2233457  2017-01-12 00:00:00.000000  C2388597  E9884325
# 8   O2334661  2017-01-14 00:00:00.000000  C0954327  E1329594
# 9   O3252629  2017-01-23 00:00:00.000000  C9403348  E9954302
# 10  O3331222  2017-01-13 00:00:00.000000  C1010398      None
# 11  O3377543  2017-01-15 00:00:00.000000  C9128574  E8843211
# 12  O4714645  2017-01-11 00:00:00.000000  C2388597  E1329594
# 13  O5511365  2017-01-22 00:00:00.000000  C3340959  E9884325
# ...

# %%
#Query 2- List all columns and rows of the Order Line table (OrdLine).
txt='''

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#        OrdNo    ProdNo  Qty
# 0   O1116324  P1445671    1
# 1   O1231231  P0036566    1
# 2   O1231231  P1445671    1
# 3   O1241518  P0036577    1
# 4   O1455122  P4200344    1
# 5   O1579999  P1556678    1
# 6   O1579999  P6677900    1
# 7   O1579999  P9995676    1
# 8   O1615141  P0036566    1
# 9   O1615141  P1445671    1
# 10  O1615141  P4200344    1
# 11  O1656777  P1445671    1
# 12  O1656777  P1556678    1
# 13  O2233457  P0036577    1
# 14  O2233457  P1445671    1
# 15  O2334661  P0036566    1
# 16  O2334661  P1412138    1
# 17  O2334661  P1556678    1
# 18  O3252629  P4200344    1
# 19  O3252629  P9995676    1
# 20  O3331222  P1412138    1
# 21  O3331222  P1556678    1
# 22  O3331222  P3455443    1
# 23  O3377543  P1445671    1
# 24  O3377543  P9995676    1
# 25  O4714645  P0036566    1
# 26  O4714645  P9995676    1
# 27  O5511365  P1412138    1
# 28  O5511365  P1445671    1
# 29  O5511365  P1556678    1
# 30  O5511365  P3455443    1
# 31  O5511365  P6677900    1
# ...

# %% [markdown]
# B) Retrieve some columns of a table example

# %%
#Query 3-List the customer number, the name (first and last), and the balance of customers.
txt='''


'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#       CustNo CustFirstName CustLastName  CustBal
# 0   C0954327         Sheri       Gordon      230
# 1   C1010398           Jim     Glussman      200
# 2   C2388597          Beth       Taylor      500
# 3   C3340959         Betty         Wise      200
# 4   C3499503           Bob         Mann        0
# 5   C8543321           Ron     Thompson       85
# 6   C8574932         Wally        Jones     1500
# 7   C8654390         Candy      Kendall       50
# 8   C9128574         Jerry        Wyatt      100
# 9   C9403348          Mike        Boren        0
# 10  C9432910         Larry       Styles      250
# 11  C9543029        Sharon      Johnson      856
# 12  C9549302          Todd        Hayes        0
# 13  C9857432         Homer        Wells      500
# 14  C9865874          Mary         Hill      150
# 15  C9943201         Harry      Sanders     1000

# %% [markdown]
# C) Filter the result set- Exact Matching on a String Column with the = Operator

# %%
#Query 4-List the customer number, the name (first and last), customer state  ,
#and the balance of customers who reside in Washington (CustState is WA).
txt='''
Select CustNo,	CustFirstName,	CustLastName,	CustState,	CustBal
From Customer
Where CustState is "WA"
'''
Q4 =  psql.sqldf(txt)
Q4
# Out:
#       CustNo CustFirstName CustLastName CustState  CustBal
# 0   C2388597          Beth       Taylor        WA      500
# 1   C3340959         Betty         Wise        WA      200
# 2   C3499503           Bob         Mann        WA        0
# 3   C8543321           Ron     Thompson        WA       85
# 4   C8574932         Wally        Jones        WA     1500
# 5   C8654390         Candy      Kendall        WA       50
# 6   C9432910         Larry       Styles        WA      250
# 7   C9543029        Sharon      Johnson        WA      856
# 8   C9549302          Todd        Hayes        WA        0
# 9   C9857432         Homer        Wells        WA      500
# 10  C9943201         Harry      Sanders        WA     1000

# %% [markdown]
# D) SQL Comparision Operator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Query 5-List the customers who has the balance less than 150$.
txt='''


'''
Q5 =  psql.sqldf(txt)
Q5
# Out:
#      CustNo CustFirstName CustLastName          CustStreet   CustCity  \
# 0  C3499503           Bob         Mann  1190 Lorraine Cir.     Monroe
# 1  C8543321           Ron     Thompson       789 122nd St.     Renton
# 2  C8654390         Candy      Kendall        456 Pine St.    Seattle
# 3  C9128574         Jerry        Wyatt     16212 123rd Ct.     Denver
# 4  C9403348          Mike        Boren      642 Crest Ave.  Englewood
# 5  C9549302          Todd        Hayes        1400 NW 88th   Lynnwood
#
#   CustState     CustZip  CustBal
# 0        WA  98013-1095        0
# 1        WA  98666-1289       85
# 2        WA  98105-3345       50
# 3        CO  80222-0022      100
# 4        CO  80113-5431        0
# 5        WA  98036-2244        0

# %%
#Query 6-List the product whose price is greater or equal to  16$.
txt='''

'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036566      17 inch Color Monitor  ColorMeg, Inc.       12     169.00
# 1  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10     319.00
# 2  P1114590  R3000 Color Laser Printer          Connex        5     699.00
# 3  P1556678  CVP Ink Jet Color Printer          Connex        8      99.00
# 4  P3455443    Color Ink Jet Cartridge          Connex       24      38.00
# 5  P4200344       36-Bit Color Scanner   UV Components       16     199.99
# 6  P6677900    Black Ink Jet Cartridge          Connex       44      25.69
# 7  P9995676     Battery Back-up System         Cybercx       12      89.00
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-02-20 00:00:00.000000
# 2  2017-01-22 00:00:00.000000
# 3  2017-01-22 00:00:00.000000
# 4  2017-01-22 00:00:00.000000
# 5  2017-01-29 00:00:00.000000
# 6                        None
# 7  2017-02-01 00:00:00.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# D) Filter the result set with Logical Operators

# %%
#Query 7. List the order number, order date, and shipping name (OrdName) and Order City (OrdCity)
#of orders sent to addresses in Denver or Englewood.
txt='''

'''
Q7 =  psql.sqldf(txt)
Q7
# Out:
#       OrdNo                     OrdDate       OrdName    OrdCity
# 0  O3252629  2017-01-23 00:00:00.000000    Mike Boren  Englewood
# 1  O3331222  2017-01-13 00:00:00.000000  Jim Glussman     Denver
# 2  O3377543  2017-01-15 00:00:00.000000   Jerry Wyatt     Denver

# %%
#Query 8-List all columns of the Product table for products costing more than $50
# and Product Quantity on hand (ProdQOH) is less than or equal to  10
txt='''

'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10      319.0
# 1  P1114590  R3000 Color Laser Printer          Connex        5      699.0
# 2  P1556678  CVP Ink Jet Color Printer          Connex        8       99.0
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-01-22 00:00:00.000000
# 2  2017-01-22 00:00:00.000000

# %%
#Query 9- List the customer number, the name (first and last), the city, and the balance of customers who reside
#in Denver with a balance greater than $150 or who reside in Seattle with a balance greater than $300.
txt='''

'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#      CustNo CustFirstName CustLastName CustCity  CustBal
# 0  C1010398           Jim     Glussman   Denver      200
# 1  C2388597          Beth       Taylor  Seattle      500
# 2  C8574932         Wally        Jones  Seattle     1500
# 3  C9857432         Homer        Wells  Seattle      500

# %% [markdown]
# E) IN and NOT IN - Exact Matching on a String Column with the IN and NOT IN

# %%
#Query 10. List the order number, order date,shipping name (OrdName) and Order City of
# orders sent to addresses in Denver or Englewood.
txt='''

'''
Q10 =  psql.sqldf(txt)
Q10
# Out:
#       OrdNo                     OrdDate       OrdName    OrdCity
# 0  O3252629  2017-01-23 00:00:00.000000    Mike Boren  Englewood
# 1  O3331222  2017-01-13 00:00:00.000000  Jim Glussman     Denver
# 2  O3377543  2017-01-15 00:00:00.000000   Jerry Wyatt     Denver

# %%
# Query 11. List the order number, order date, shipping name (OrdName) and
#Order City of orders sent to addresses other than  Denver and  Englewood.
txt='''


'''
Q11 =  psql.sqldf(txt)
Q11
# Out:
#        OrdNo                     OrdDate           OrdName     OrdCity
# 0   O1116324  2017-01-23 00:00:00.000000      Sheri Gordon   Littleton
# 1   O1231231  2017-01-23 00:00:00.000000      Larry Styles    Bellevue
# 2   O1241518  2017-02-10 00:00:00.000000        Todd Hayes    Lynnwood
# 3   O1455122  2017-01-09 00:00:00.000000       Wally Jones     Seattle
# 4   O1579999  2017-01-05 00:00:00.000000       Tom Johnson  Des Moines
# 5   O1615141  2017-01-23 00:00:00.000000     Candy Kendall     Seattle
# 6   O1656777  2017-02-11 00:00:00.000000      Ron Thompson      Renton
# 7   O2233457  2017-01-12 00:00:00.000000       Beth Taylor     Seattle
# 8   O2334661  2017-01-14 00:00:00.000000  Mrs. Ruth Gordon     Seattle
# 9   O4714645  2017-01-11 00:00:00.000000       Beth Taylor     Seattle
# 10  O5511365  2017-01-22 00:00:00.000000       Betty White     Seattle
# 11  O6565656  2017-01-20 00:00:00.000000   Mr. Jack Sibley      Renton
# ...

# %%
# Query 11A. List the order number, order date, shipping name (OrdName) and
#Order City of orders sent to addresses other than  Denver and  Englewood.
txt='''


'''
Q11A =  psql.sqldf(txt)
Q11A
# Out:
#        OrdNo                     OrdDate           OrdName     OrdCity
# 0   O1116324  2017-01-23 00:00:00.000000      Sheri Gordon   Littleton
# 1   O1231231  2017-01-23 00:00:00.000000      Larry Styles    Bellevue
# 2   O1241518  2017-02-10 00:00:00.000000        Todd Hayes    Lynnwood
# 3   O1455122  2017-01-09 00:00:00.000000       Wally Jones     Seattle
# 4   O1579999  2017-01-05 00:00:00.000000       Tom Johnson  Des Moines
# 5   O1615141  2017-01-23 00:00:00.000000     Candy Kendall     Seattle
# 6   O1656777  2017-02-11 00:00:00.000000      Ron Thompson      Renton
# 7   O2233457  2017-01-12 00:00:00.000000       Beth Taylor     Seattle
# 8   O2334661  2017-01-14 00:00:00.000000  Mrs. Ruth Gordon     Seattle
# 9   O4714645  2017-01-11 00:00:00.000000       Beth Taylor     Seattle
# 10  O5511365  2017-01-22 00:00:00.000000       Betty White     Seattle
# 11  O6565656  2017-01-20 00:00:00.000000   Mr. Jack Sibley      Renton
# ...

# %% [markdown]
# F) Eliminating Duplicates with DISTINCT

# %%
#Query 12a. List the cities  where orders have been placed.
txt='''

'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#        OrdCity
# 0    Littleton
# 1     Bellevue
# 2     Lynnwood
# 3      Seattle
# 4   Des Moines
# 5      Seattle
# 6       Renton
# 7      Seattle
# 8      Seattle
# 9    Englewood
# 10      Denver
# 11      Denver
# 12     Seattle
# 13     Seattle
# 14      Renton
# 15        Fife
# 16      Renton
# 17      Monroe
# 18      Renton
# 19     Seattle

# %%
#Query 12b. List the cities  where orders have been placed.
#Remove duplicates from the result.
txt='''

'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#       OrdCity
# 0   Littleton
# 1    Bellevue
# 2    Lynnwood
# 3     Seattle
# 4  Des Moines
# 5      Renton
# 6   Englewood
# 7      Denver
# 8        Fife
# 9      Monroe

# %% [markdown]
# E) Is null or Is not null

# %%
#Query 13. List all columns of the OrderTbl table for Internet orders  .
# An Internet order does not have an associated employee.
txt='''

'''
Q13 =  psql.sqldf(txt)
Q13
# Out:
#       OrdNo                     OrdDate    CustNo EmpNo        OrdName  \
# 0  O1241518  2017-02-10 00:00:00.000000  C9549302  None     Todd Hayes
# 1  O1656777  2017-02-11 00:00:00.000000  C8543321  None   Ron Thompson
# 2  O3331222  2017-01-13 00:00:00.000000  C1010398  None   Jim Glussman
# 3  O7847172  2017-01-23 00:00:00.000000  C9943201  None  Harry Sanders
# 4  O8979495  2017-01-23 00:00:00.000000  C9865874  None    HelenSibley
#
#           OrdStreet   OrdCity OrdState      OrdZip
# 0      1400 NW 88th  Lynnwood       WA  98036-2244
# 1     789 122nd St.    Renton       WA  98666-1289
# 2   1432 E. Ravenna    Denver       CO  80111-0033
# 3  1280 S. Hill Rd.      Fife       WA  98222-2258
# 4     206 McCaffrey    Renton       WA  98006-5543

# %%
#Query 14. List all columns of the OrderTbl table for Regular orders .
#An Regular orderhave an associated employee.
txt='''


'''
Q14 =  psql.sqldf(txt)
Q14
# Out:
#        OrdNo                     OrdDate    CustNo     EmpNo  \
# 0   O1116324  2017-01-23 00:00:00.000000  C0954327  E8544399
# 1   O1231231  2017-01-23 00:00:00.000000  C9432910  E9954302
# 2   O1455122  2017-01-09 00:00:00.000000  C8574932  E9345771
# 3   O1579999  2017-01-05 00:00:00.000000  C9543029  E8544399
# 4   O1615141  2017-01-23 00:00:00.000000  C8654390  E8544399
# 5   O2233457  2017-01-12 00:00:00.000000  C2388597  E9884325
# 6   O2334661  2017-01-14 00:00:00.000000  C0954327  E1329594
# 7   O3252629  2017-01-23 00:00:00.000000  C9403348  E9954302
# 8   O3377543  2017-01-15 00:00:00.000000  C9128574  E8843211
# 9   O4714645  2017-01-11 00:00:00.000000  C2388597  E1329594
# 10  O5511365  2017-01-22 00:00:00.000000  C3340959  E9884325
# 11  O6565656  2017-01-20 00:00:00.000000  C9865874  E8843211
# 12  O7959898  2017-02-19 00:00:00.000000  C8543321  E8544399
# 13  O7989497  2017-01-16 00:00:00.000000  C3499503  E9345771
# ...

# %% [markdown]
# G) Inexact Matching with the LIKE Operator Example

# %% [markdown]
# The LIKE operator is used in a WHERE clause to search for a specified pattern in a column.
#
# There are two wildcards often used in conjunction with the LIKE operator:
#
# The percent sign (%) represents zero, one, or multiple characters. The underscore sign (_) represents one, single character
#
# Note: MS Access uses an asterisk (*) instead of the percent sign (%), and a question mark (?) instead of the underscore (_).

# %%
#16. List all columns of the Product table that
# contain the words Ink Jet in the product name.
txt='''

'''
Q16 =  psql.sqldf(txt)
Q16
# Out:
#      ProdNo                   ProdName ProdMfg  ProdQOH  ProdPrice  \
# 0  P1556678  CVP Ink Jet Color Printer  Connex        8      99.00
# 1  P3455443    Color Ink Jet Cartridge  Connex       24      38.00
# 2  P6677900    Black Ink Jet Cartridge  Connex       44      25.69
#
#              ProdNextShipDate
# 0  2017-01-22 00:00:00.000000
# 1  2017-01-22 00:00:00.000000
# 2                        None

# %%
#17. List all columns of the OrderTbl table
#for Internet orders placed in January 2017  .
#An Internet order does not have an associated employee.
txt='''

'''
Q17 =  psql.sqldf(txt)
Q17
# Out:
#       OrdNo                     OrdDate    CustNo EmpNo        OrdName  \
# 0  O3331222  2017-01-13 00:00:00.000000  C1010398  None   Jim Glussman
# 1  O7847172  2017-01-23 00:00:00.000000  C9943201  None  Harry Sanders
# 2  O8979495  2017-01-23 00:00:00.000000  C9865874  None    HelenSibley
#
#           OrdStreet OrdCity OrdState      OrdZip
# 0   1432 E. Ravenna  Denver       CO  80111-0033
# 1  1280 S. Hill Rd.    Fife       WA  98222-2258
# 2     206 McCaffrey  Renton       WA  98006-5543

# %%
#17A. List all columns of the Product table that
# contain the words Color in the product name.
txt='''

'''
Q17A =  psql.sqldf(txt)
Q17A
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036566      17 inch Color Monitor  ColorMeg, Inc.       12     169.00
# 1  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10     319.00
# 2  P1114590  R3000 Color Laser Printer          Connex        5     699.00
# 3  P1556678  CVP Ink Jet Color Printer          Connex        8      99.00
# 4  P3455443    Color Ink Jet Cartridge          Connex       24      38.00
# 5  P4200344       36-Bit Color Scanner   UV Components       16     199.99
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-02-20 00:00:00.000000
# 2  2017-01-22 00:00:00.000000
# 3  2017-01-22 00:00:00.000000
# 4  2017-01-22 00:00:00.000000
# 5  2017-01-29 00:00:00.000000

# %%
#17A. List all columns of the Product table that
# product name start with  the words Color .
txt='''

'''
Q17A =  psql.sqldf(txt)
Q17A
# Out:
#      ProdNo                 ProdName ProdMfg  ProdQOH  ProdPrice  \
# 0  P3455443  Color Ink Jet Cartridge  Connex       24       38.0
#
#              ProdNextShipDate
# 0  2017-01-22 00:00:00.000000

# %%
#17A. List all columns of the Product table that
# the word 'Color' appers only in the middle of product name   .
txt='''

'''
Q17A =  psql.sqldf(txt)
Q17A
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036566      17 inch Color Monitor  ColorMeg, Inc.       12     169.00
# 1  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10     319.00
# 2  P1114590  R3000 Color Laser Printer          Connex        5     699.00
# 3  P1556678  CVP Ink Jet Color Printer          Connex        8      99.00
# 4  P4200344       36-Bit Color Scanner   UV Components       16     199.99
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-02-20 00:00:00.000000
# 2  2017-01-22 00:00:00.000000
# 3  2017-01-22 00:00:00.000000
# 4  2017-01-29 00:00:00.000000

# %%
#17A. List all columns of the Product table that
# the word 'Color' appers only in the middle of product name   .
txt='''

'''
Q17A =  psql.sqldf(txt)
Q17A
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036566      17 inch Color Monitor  ColorMeg, Inc.       12     169.00
# 1  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10     319.00
# 2  P1114590  R3000 Color Laser Printer          Connex        5     699.00
# 3  P1556678  CVP Ink Jet Color Printer          Connex        8      99.00
# 4  P4200344       36-Bit Color Scanner   UV Components       16     199.99
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-02-20 00:00:00.000000
# 2  2017-01-22 00:00:00.000000
# 3  2017-01-22 00:00:00.000000
# 4  2017-01-29 00:00:00.000000

# %% [markdown]
# H) Sorting with Order By

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ASC-Ascending-1-A to Z-Default-if ASC or DESC is absent in order by, it is assumed as ASC
#DESC-Descending-Z to A
#Query 18-#List all columns of the Product table for products
#costing more than $50. Order the result by product manufacturer
 #(ProdMfg) and product name by descending order.
txt='''

'''
Q18 =  psql.sqldf(txt)
Q18
# Out:
#      ProdNo                   ProdName         ProdMfg  ProdQOH  ProdPrice  \
# 0  P0036577      19 inch Color Monitor  ColorMeg, Inc.       10     319.00
# 1  P0036566      17 inch Color Monitor  ColorMeg, Inc.       12     169.00
# 2  P1114590  R3000 Color Laser Printer          Connex        5     699.00
# 3  P1556678  CVP Ink Jet Color Printer          Connex        8      99.00
# 4  P9995676     Battery Back-up System         Cybercx       12      89.00
# 5  P4200344       36-Bit Color Scanner   UV Components       16     199.99
#
#              ProdNextShipDate
# 0  2017-02-20 00:00:00.000000
# 1  2017-02-20 00:00:00.000000
# 2  2017-01-22 00:00:00.000000
# 3  2017-01-22 00:00:00.000000
# 4  2017-02-01 00:00:00.000000
# 5  2017-01-29 00:00:00.000000

# %% [markdown]
# I) Aggregate Function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q19-What is the minumum, maximum, average customer balance.
# How many customer are there in customer table?
#Note:If there is no null value in the column, count(*) and count(FieldName) will give the same result.
txt='''

'''
Q19 =  psql.sqldf(txt)
Q19
# Out:
#    MinCustBal  MaxCustBal  AvgCustBal  No Of Customer
# 0           0        1500    351.3125              16

# %%
#Regular orders are the orders with assigned EmployeeNo
#internet Orders are the orders with no assigned EmployeeNo
#Q20-How many regular orders and total orders(internet+regular) are there in Order table?
txt='''

'''
Q20 =  psql.sqldf(txt)
Q20
# Out:
#    No of Regular Orders  No of Total Orders
# 0                    15                  20

# %%
#Q21-How many internet orders are there in Order Table?
txt='''

'''
Q21 =  psql.sqldf(txt)
Q21
# Out:
#    No of InterNet Order
# 0                     5

# %%
#Regular orders are the orders with assigned EmployeeNo
#internet Orders are the orders with no assigned EmployeeNo
#Q20-How many regular orders and total orders(internet+regular) are there in Order table?
txt='''

'''
Q20 =  psql.sqldf(txt)
Q20
# Out:
#    No of Regular Orders  No of Total Orders  No of Internet Orders
# 0                    15                  20                      5

# %% [markdown]
# J) Summarizing Tables with GROUP BY and HAVING

# %%
#Q22-Summarize average product prices by Product Manafucturer
txt='''


'''
Q22 =  psql.sqldf(txt)
Q22
# Out:
#           ProdMfg  AvgProdPrice
# 0  ColorMeg, Inc.      244.0000
# 1          Connex      215.4225
# 2         Cybercx       89.0000
# 3         Ethlite       12.0000
# 4       Intersafe       14.9900
# 5   UV Components      199.9900

# %%
#Q23-Find number of orders by city?
txt='''

'''
Q23=  psql.sqldf(txt)
Q23
# Out:
#       OrdCity  No Of Orders
# 0    Bellevue             1
# 1      Denver             2
# 2  Des Moines             1
# 3   Englewood             1
# 4        Fife             1
# 5   Littleton             1
# 6    Lynnwood             1
# 7      Monroe             1
# 8      Renton             4
# 9     Seattle             7

# %%
#Q23-Find number of orders by city? Sort number of orders
#From highest to lowest number
txt='''

'''
Q23=  psql.sqldf(txt)
Q23
# Out:
#       OrdCity  No Of Orders
# 0     Seattle             7
# 1      Renton             4
# 2      Denver             2
# 3      Monroe             1
# 4    Lynnwood             1
# 5   Littleton             1
# 6        Fife             1
# 7   Englewood             1
# 8  Des Moines             1
# 9    Bellevue             1

# %%
#Q24-Find number of orders handled by Employee
txt='''

'''
Q24=  psql.sqldf(txt)
Q24
# Out:
#       EmpNo  NoOfOrders
# 0      None           5
# 1  E1329594           2
# 2  E8544399           4
# 3  E8843211           2
# 4  E9345771           2
# 5  E9884325           2
# 6  E9954302           3

# %%
#Q24-Find number of orders handled by Employee
#Do not include internet orders
txt='''


'''
Q24=  psql.sqldf(txt)
Q24
# Out:
#       EmpNo  NoOfOrders
# 0  E1329594           2
# 1  E8544399           4
# 2  E8843211           2
# 3  E9345771           2
# 4  E9884325           2
# 5  E9954302           3

# %%
#Q25. List the average balance of customers by city.
txt='''

'''
Q25=  psql.sqldf(txt)
Q25
# Out:
#     CustCity  AvgCustBal
# 0   Bellevue       250.0
# 1     Denver       150.0
# 2  Englewood         0.0
# 3       Fife       928.0
# 4  Littleton       190.0
# 5   Lynnwood         0.0
# 6     Monroe         0.0
# 7     Renton        85.0
# 8    Seattle       550.0

# %%
#Q26. List the average balance of customers by city.
#Include number of customer in each city as well.
#Include only customers residing in Washington state (WA).
txt='''


'''
Q26=  psql.sqldf(txt)
Q26
# Out:
#    CustCity CustState  AvgCustBal  NoOfCustomer
# 0  Bellevue        WA       250.0             1
# 1      Fife        WA       928.0             2
# 2  Lynnwood        WA         0.0             1
# 3    Monroe        WA         0.0             1
# 4    Renton        WA        85.0             1
# 5   Seattle        WA       550.0             5

# %%
#Q27. List the average balance and number of customers by city.
#Include number of customer in each city as well.
# Only include customers residing in Washington State (WA).
# Eliminate cities in the result with less than two customers.
txt='''


'''
Q27=  psql.sqldf(txt)
Q27
# Out:
#   CustCity CustState  AvgCustBal  NoOfCustomer
# 0     Fife        WA       928.0             2
# 1  Seattle        WA       550.0             5

# %%
#Q28. How many orders given for each customer
txt='''

'''
Q28 =  psql.sqldf(txt)
Q28
# Out:
#       CustNo  NoOfCustomer
# 0   C0954327             2
# 1   C1010398             1
# 2   C2388597             2
# 3   C3340959             1
# 4   C3499503             1
# 5   C8543321             2
# 6   C8574932             1
# 7   C8654390             1
# 8   C9128574             1
# 9   C9403348             1
# 10  C9432910             1
# 11  C9543029             1
# 12  C9549302             1
# 13  C9857432             1
# 14  C9865874             2
# 15  C9943201             1

# %%
#Q29. Find customer who give  orders more than 1.
txt='''

'''
Q29 =  psql.sqldf(txt)
Q29
# Out:
#      CustNo  NoOfCustomer
# 0  C0954327             2
# 1  C2388597             2
# 2  C8543321             2
# 3  C9865874             2

# %%
#Q30-How many products are there in each order?
txt='''

'''
Q30 =  psql.sqldf(txt)
Q30
# Out:
#        OrdNo  NoOfProduct
# 0   O1116324            1
# 1   O1231231            2
# 2   O1241518            1
# 3   O1455122            1
# 4   O1579999            3
# 5   O1615141            3
# 6   O1656777            2
# 7   O2233457            2
# 8   O2334661            3
# 9   O3252629            2
# 10  O3331222            3
# 11  O3377543            2
# 12  O4714645            2
# 13  O5511365            5
# 14  O6565656            1
# 15  O7847172            2
# 16  O7959898            4
# 17  O7989497            3
# 18  O8979495            3
# 19  O9919699            3

# %%
#Q31-How many times each prouct ordered?
#find total quantity ordered for those product as well
txt='''

'''
Q31 =  psql.sqldf(txt)
Q31
# Out:
#      ProdNo  NoOfOrder  TotalQuantityOrdered
# 0  P0036566          5                    14
# 1  P0036577          3                     3
# 2  P1114590          3                     4
# 3  P1412138          6                    11
# 4  P1445671          9                    11
# 5  P1556678          7                    11
# 6  P3455443          3                     7
# 7  P4200344          4                     4
# 8  P6677900          4                     8
# 9  P9995676          4                     4

# %%
#Q32-Count numbr of cities in each state in customers address
#Find number of customer in each state

txt='''

'''
Q32 =  psql.sqldf(txt)
Q32
# Out:
#   CustState  NoOfCity  NoOfCustomer
# 0        CO         3             5
# 1        WA         6            11

# %% [markdown]
#  UNION, UNION ALL, INTERSECT, EXCEPT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q33A. Find distinct  cities in customer address
txt='''

'''
Q33A =  psql.sqldf(txt)
Q33A
# Out:
#     CustCity
# 0  Littleton
# 1     Denver
# 2    Seattle
# 3     Monroe
# 4     Renton
# 5  Englewood
# 6   Bellevue
# 7       Fife
# 8   Lynnwood

# %%
#Q33B. Find distinct cities in Order address (OrdCity)
txt='''

'''
Q33B =  psql.sqldf(txt)
Q33B
# Out:
#       OrdCity
# 0   Littleton
# 1    Bellevue
# 2    Lynnwood
# 3     Seattle
# 4  Des Moines
# 5      Renton
# 6   Englewood
# 7      Denver
# 8        Fife
# 9      Monroe

# %%
#Q34. Combine all cities in customer and order address
txt='''


'''
Q34=  psql.sqldf(txt)
Q34
# Out:
#          City
# 0    Bellevue
# 1      Denver
# 2  Des Moines
# 3   Englewood
# 4        Fife
# 5   Littleton
# 6    Lynnwood
# 7      Monroe
# 8      Renton
# 9     Seattle

# %%
#Query 35-Combine all cities in customer and order address.
#Include duplicates record as well
txt='''

'''
Q35=  psql.sqldf(txt)
Q35
# Out:
#           City
# 0    Littleton
# 1       Denver
# 2      Seattle
# 3      Seattle
# 4       Monroe
# 5       Renton
# 6      Seattle
# 7      Seattle
# 8       Denver
# 9    Englewood
# 10    Bellevue
# 11        Fife
# 12    Lynnwood
# 13     Seattle
# 14   Littleton
# 15        Fife
# 16   Littleton
# 17    Bellevue
# 18    Lynnwood
# 19     Seattle
# 20  Des Moines
# 21     Seattle
# 22      Renton
# 23     Seattle
# 24     Seattle
# 25   Englewood
# 26      Denver
# 27      Denver
# 28     Seattle
# 29     Seattle
# 30      Renton
# 31        Fife
# 32      Renton
# 33      Monroe
# 34      Renton
# 35     Seattle

# %%
#Query 36-Combine all cities appeared in both customer and order addresses.
txt='''

'''
Q36=  psql.sqldf(txt)
Q36
# Out:
#         City
# 0   Bellevue
# 1     Denver
# 2  Englewood
# 3       Fife
# 4  Littleton
# 5   Lynnwood
# 6     Monroe
# 7     Renton
# 8    Seattle

# %%
#Query 37-List all cities appeared in  customer  addresses but not in order address.
txt='''

'''
Q37=  psql.sqldf(txt)
Q37
# Out:
# Empty DataFrame
# Columns: [CustCity]
# Index: []

# %%
#Query 38-List all cities appeared in  order  addresses but not in customer address.
txt='''


'''
Q38=  psql.sqldf(txt)
Q38
# Out:
#       OrdCity
# 0  Des Moines
